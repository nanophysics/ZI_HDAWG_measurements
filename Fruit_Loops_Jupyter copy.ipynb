# %%
#general imports
# %config IPCompleter.greedy=True 
import numpy as np
import time
import zhinst.core
import laboneq
from laboneq.simple import *
import ctypes
import helpers
from picosdk.ps5000a import ps5000a as ps 
from picosdk.functions import adc2mV, assert_pico_ok#, mVadc (can't import for some reason) 
import picoscope_module as pm 
import configparser

DO_EMULATION = False # run in emulation mode by default 

descriptor = config.get('ZurichInstruments', 'descriptor')

# create and connect to session
device_setup = DeviceSetup.from_descriptor(descriptor,server_host="127.0.0.1",server_port="8004", setup_name="ZI_HDAWG")
session = Session(device_setup=device_setup)
session.connect(do_emulation=DO_EMULATION)
if not session.connection_state.emulated:
    instrument_serial = device_setup.instrument_by_uid("device_hdawg").address
    device = session.devices[instrument_serial]
    device.triggers.out[2].delay(23.9e-9)

#picoscope 
params = {key: float(value) for key, value in config['PicoscopeParameters'].items()}
pico_sampling_rate = (params['timebase'] - 3) / 62500000
postTriggerSamples = int(np.ceil(params['postTriggerSamples_val'] / pico_sampling_rate))
maxSamples = preTriggerSamples + postTriggerSamples

NUM_REP = 50

compress_level_pulse=pulse_library.const(uid="compress_level",length=times_map['pulse_time'],amplitude=1,can_compress=True)

chandle, status = pm.initialize_picoscope()
status, chARange, chBRange = pm.setup_channels(chandle)
status,maxADC = pm.setup_trigger(chandle, chARange, chBRange, TriggerLevel)


#defining parameters 
times_map = {
    'pulse_time': 10e-3, 
    'dead_time': 10e-3, 
    'trigger_time': 1e-3
}

# assign amplitude to received variable
x_p = np.linspace(0.1, -0.1, 21)
y_p = np.linspace(0.1, -0.1, 21)

x_mesh, y_mesh = np.meshgrid(x_p, y_p)
tensor_product = np.column_stack((x_mesh.ravel(), y_mesh.ravel()))

#define pulse shapes
#@pulse_library.register_pulse_functional
#def ramp(x,start=0,stop=1,**_):
#    pulse=start+ (stop-start)*(x+1)/2
#    return pulse


for received_variable in range(len(x_p)*len(y_p)):
    read_amplitude=tensor_product[received_variable]
    
    # Experiment
    exp = Experiment(
        "Pulse Experiment",
        signals=[
            ExperimentSignal("gate1"),
            ExperimentSignal("gate2"),
        ],
    )

    with exp.acquire_loop_rt(
        uid=("pulse"), count=NUM_REP, averaging_mode=AveragingMode.SEQUENTIAL
    ):
        with exp.section(
            uid=("unload"),
            length=times_map['pulse_time'],
            trigger={"gate1":{"state":1}},
            alignment=SectionAlignment.LEFT,
        ):
            exp.play(signal="gate1",pulse=compress_level_pulse,amplitude=-0.1)
            exp.play(signal="gate2",pulse=compress_level_pulse,amplitude=-0.1)
        with exp.section(
            uid=("load"),
            length=times_map['pulse_time'],
            alignment=SectionAlignment.LEFT,
        ):
            exp.play(signal="gate1",pulse=compress_level_pulse,amplitude=0.1)
            exp.play(signal="gate2",pulse=compress_level_pulse,amplitude=-0.1)
        with exp.section(
            uid=("measure"),
            length=times_map['pulse_time'],
            alignment=SectionAlignment.LEFT, 
        ): 
            exp.play(signal="gate1",pulse=compress_level_pulse,amplitude=read_amplitude[0])
            exp.play(signal="gate2",pulse=compress_level_pulse,amplitude=read_amplitude[1])

    #shortcut to the logical signal group q0
    lsg = device_setup.logical_signal_groups["q0"].logical_signals

    #define signal map
    map_signals ={
        "gate1" : lsg["fg4_line"],
        "gate2" : lsg["fg6_line"]
    }

    
    noOfCaptures = NUM_REP
    status,timeIntervalns = pm.capture_rapid_data_block(chandle, preTriggerSamples, postTriggerSamples, timebase, maxSamples,noOfCaptures)


    # set experiment calibration and signal map
    exp.set_signal_map(map_signals)
        
    print("Loaded exp")
    session.run(exp)
    print("Running exp finished")

    # # Check for data collection to finish using ps5000aIsReady
    status = pm.check_ready(chandle, status)

    source = ps.PS5000A_CHANNEL["PS5000A_CHANNEL_B"]
    buffersMax, buffersMin = pm.create_rapid_buffer(chandle, source, maxSamples, noOfCaptures)
    pm.getValuesRapid(chandle,maxSamples,noOfCaptures)

    # #postprocessing
    # # convert ADC counts data to mV
    cmaxSamples = ctypes.c_int32(maxSamples)

    # # Create time data
    time_array = pm.create_time_data(maxSamples, timeIntervalns)
    with open('Data/pulses_%s_a=%s.npy'%(time_stamp,read_amplitude), 'wb') as f:
        np.save(f,time_array)
        for i in range(noOfCaptures):
            np.save(f,adc2mV(buffersMax[i], chARange, maxADC))
            
    # Stop the scope
    status = pm.stop_picoscope(chandle,status)

    # Close unit Disconnect the scope 
pm.close_picoscope
# Out:
# c:\Users\B15measure2\anaconda3\envs\laboneq\lib\site-packages\laboneq\dsl\device\_device_setup_generator.py:1104: FutureWarning: 'instrument_list' section is deprecated in setup descriptor, use 'instruments' instead.
#   warnings.warn(
# 2023.08.22 18:00:38.040 laboneq.controller.laboneq_logging INFO   Logging initialized from [Default inline config in laboneq.controller.laboneq_logging] logdir is c:\Users\B15measure2\HDAWG\laboneq_output\log
# 2023.08.22 18:00:38.042 laboneq.controller.controller  INFO   VERSION: laboneq 2.11.0
# 2023.08.22 18:00:38.043 laboneq.controller.devices.device_collection INFO   Connecting to data server at 127.0.0.1:8004
# 2023.08.22 18:00:38.253 laboneq.controller.communication INFO   Connected to Zurich Instruments LabOne Data Server version 23.02 at 127.0.0.1:8004
# 2023.08.22 18:00:39.111 laboneq.controller.devices.device_collection INFO   Configuring the device setup
# 2023.08.22 18:00:39.300 laboneq.controller.devices.device_collection INFO   The device setup is configured
# Loaded exp
# 2023.08.22 18:00:40.569 laboneq.compiler.workflow.compiler INFO   Starting LabOne Q Compiler run...
# 2023.08.22 18:00:40.575 laboneq.compiler.scheduler.scheduler INFO   Schedule completed
# 2023.08.22 18:00:53.967 laboneq.compiler.workflow.compiler INFO   Total seqC lines generated: 40
# 2023.08.22 18:00:53.969 laboneq.compiler.workflow.compiler INFO   Total sample points generated: 192
# 2023.08.22 18:00:53.970 laboneq.compiler.workflow.compiler INFO   Finished LabOne Q Compiler run.
# 2023.08.22 18:00:54.268 laboneq.controller.devices.device_collection INFO   Configuring the device setup
# 2023.08.22 18:00:54.450 laboneq.controller.devices.device_collection INFO   The device setup is configured
# 2023.08.22 18:00:54.762 laboneq.controller.controller  INFO   Starting near-time execution...
# 2023.08.22 18:00:56.526 laboneq.controller.controller  INFO   Finished near-time execution.
# Running exp finished
# ---------------------------------------------------------------------------
# PicoSDKCtypesError                        Traceback (most recent call last)
# Cell In[1], line 129
#     127 source = ps.PS5000A_CHANNEL["PS5000A_CHANNEL_B"]
#     128 noOfCaptures = NUM_REP
# --> 129 status,timeIntervalns = pm.capture_rapid_data_block(chandle, preTriggerSamples, postTriggerSamples, timebase, maxSamples,noOfCaptures)
#     134 if not session.connection_state.emulated:
#     135     instrument_serial = device_setup.instrument_by_uid("device_hdawg").address
#
# File c:\Users\B15measure2\HDAWG\picoscope_module.py:151, in capture_rapid_data_block(chandle, preTriggerSamples, postTriggerSamples, timebase, maxSamples, noOfCaptures)
#     148 cmaxSamples = ctypes.c_int32(maxSamples)
#     150 status["MemorySegments"] = ps.ps5000aMemorySegments(chandle, noOfCaptures, ctypes.byref(cmaxSamples))
# --> 151 assert_pico_ok(status["MemorySegments"])
#     152 status["SetNoOfCaptures"] = ps.ps5000aSetNoOfCaptures(chandle, noOfCaptures)
#     153 assert_pico_ok(status["SetNoOfCaptures"])
#
# File c:\Users\B15measure2\anaconda3\envs\laboneq\lib\site-packages\picosdk\functions.py:160, in assert_pico_ok(status)
#     158 # checks for PICO_OK status return
#     159 if status != PICO_STATUS['PICO_OK']:
# --> 160     raise PicoSDKCtypesError("PicoSDK returned '{}'".format(PICO_STATUS_LOOKUP[status]))
#
# PicoSDKCtypesError: PicoSDK returned 'PICO_INVALID_HANDLE'
