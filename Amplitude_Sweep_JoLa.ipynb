# %%
# %config IPCompleter.greedy=True

# import matplotlib.pyplot as plt
import numpy as np
import time
import zhinst.core
import laboneq
from laboneq.simple import *
import ctypes
import helpers
import matplotlib.pyplot as plt
from picosdk.ps5000a import ps5000a as ps
from picosdk.functions import adc2mV, assert_pico_ok, mV2adc
import picoscope_module as pm
#install_token("LabOneQ.AllQuantumInOne.")
DO_EMULATION = False # run in emulation mode by default

print(laboneq.__version__)
# Out:
# 2.11.0

# %%
descriptor="""
instrument_list:
  HDAWG:
  - address: DEV8721
    uid: device_hdawg
    interface: usb
connections:
  device_hdawg:
    - rf_signal: q0/fg4_line
      ports: [SIGOUTS/0]
    - rf_signal: q0/fg6_line
      ports: [SIGOUTS/1]
"""
#Change back to to SIGOUTS/2 and SIGOUTS/3
#And change fg8 and fg9
device_setup = DeviceSetup.from_descriptor(
    descriptor,
    server_host="127.0.0.1",
    server_port="8004",
    setup_name="ZI_HDAWG",
)
# Out:
# c:\Users\B15measure2\anaconda3\envs\laboneq\lib\site-packages\laboneq\dsl\device\_device_setup_generator.py:1104: FutureWarning: 'instrument_list' section is deprecated in setup descriptor, use 'instruments' instead.
#   warnings.warn(

# %%
amplitudes_map=np.linspace(0.01,0.1, 20)

for amplitude in amplitudes_map:   
    for rep in range(1):


        points_map={
            'level1': [-amplitude, amplitude], 
            'level2': [amplitude, -amplitude],
            'level3': [amplitude, -amplitude],
        }

        times_map = {'pulse_time': 20e-3, #was 10
                    'dead_time': 20e-3,
                    'trigger_time': 1e-3}
        

        compress_level_pulse_level1_gate1=pulse_library.const(uid="compress_levell1g1",length=times_map['pulse_time'],amplitude=points_map['level1'][0],can_compress=True)
        compress_level_pulse_level1_gate2=pulse_library.const(uid="compress_levell1g2",length=times_map['pulse_time'],amplitude=points_map['level1'][1],can_compress=True)
        compress_level_pulse_level2_gate1=pulse_library.const(uid="compress_levell2g1",length=times_map['pulse_time'],amplitude=points_map['level2'][0],can_compress=True)
        compress_level_pulse_level2_gate2=pulse_library.const(uid="compress_levell2g2",length=times_map['pulse_time'],amplitude=points_map['level2'][1],can_compress=True)
        compress_level_pulse_level3_gate1=pulse_library.const(uid="compress_levell3g1",length=times_map['dead_time'],amplitude=points_map['level3'][0],can_compress=True)
        compress_level_pulse_level3_gate2=pulse_library.const(uid="compress_levell3g2",length=times_map['dead_time'],amplitude=points_map['level3'][1],can_compress=True)



        timebase = 628
        preTriggerSamples = 10
        pico_sampling_rate = (timebase - 3) / 62500000
        postTriggerSamples = int(np.ceil(40e-3/pico_sampling_rate)) #Measurment length was 8
        TriggerLevel=1

        maxSamples = preTriggerSamples + postTriggerSamples
        ready = ctypes.c_int16(0)
        check = ctypes.c_int16(0)
        maxADC = ctypes.c_int16()

    ## Create Experiment
        exp = Experiment(
            "Singlet-triplet qubit example",
            signals=[
                ExperimentSignal("gate1"),
                ExperimentSignal("gate2"),
            ],
        )

        # define experiment
        NUM_REP = 30


        with exp.acquire_loop_rt(  #This is no loop, he executes this ones
            uid=("shots"), count=NUM_REP, averaging_mode=AveragingMode.SEQUENTIAL
        ):


            with exp.section(
                uid=("level1"),
                length=times_map['pulse_time'], 
                trigger={"gate1": {"state": 1}}, 
                alignment=SectionAlignment.LEFT,
            ):
                exp.play(signal="gate1", pulse=compress_level_pulse_level1_gate1)
                exp.play(signal="gate2", pulse=compress_level_pulse_level1_gate2)    
            with exp.section(
                uid=("level2"),
                length=times_map['pulse_time'], 
                alignment=SectionAlignment.LEFT,
            ):
                exp.play(signal="gate1", pulse=compress_level_pulse_level2_gate1)
                exp.play(signal="gate2", pulse=compress_level_pulse_level2_gate2)

            with exp.section(
                uid=("level3"),
                length=times_map['dead_time'], 
                alignment=SectionAlignment.LEFT,
            ):
                exp.play(signal="gate1", pulse=compress_level_pulse_level3_gate1)
                exp.play(signal="gate2", pulse=compress_level_pulse_level3_gate2)


                # shortcut to the logical signal group q0
        lsg = device_setup.logical_signal_groups["q0"].logical_signals

        # define signal map
        map_signals = {
            "gate1" : lsg["fg4_line"],
            "gate2" : lsg["fg6_line"]
        }
        # # create and connect to session
        session = Session(device_setup=device_setup)
        session.connect(do_emulation=DO_EMULATION)
        # set experiment calibration and signal map
        exp.set_signal_map(map_signals)



        chandle, status = pm.initialize_picoscope()
        chARange, chBRange, status = pm.setup_channels(chandle)
        # find maximum ADC count value

        pm.setup_trigger(chandle, chARange, chBRange, maxADC, TriggerLevel)



        source = ps.PS5000A_CHANNEL["PS5000A_CHANNEL_B"] #set the buffer
        noOfCaptures = NUM_REP
        status,timeIntervalns = pm.capture_rapid_data_block(chandle, preTriggerSamples, postTriggerSamples, timebase, maxSamples,noOfCaptures)






        if not session.connection_state.emulated:
            instrument_serial = device_setup.instrument_by_uid("device_hdawg").address
            device = session.devices[instrument_serial]
            device.triggers.out[2].delay(23.9e-9)
        print("Loaded exp")
        session.run(exp)
        print("Running exp finished")
        # Check for data collection to finish using ps5000aIsReady
        while ready.value == check.value:
            status["isReady"] = ps.ps5000aIsReady(chandle, ctypes.byref(ready))

        buffersMax, buffersMin = pm.create_rapid_buffer(chandle, source, maxSamples, noOfCaptures)
        pm.getValuesRapid(chandle,maxSamples,noOfCaptures)



        # convert ADC counts data to mV
        cmaxSamples = ctypes.c_int32(maxSamples)

        # Create time data
        time_stamp=int(time.time())
        time_array = np.linspace(0, (cmaxSamples.value - 1) * timeIntervalns.value, cmaxSamples.value)
        with open('Data/data_%s_amp_%iuV_rep_%i.npy'%(time_stamp, amplitude*1000, rep), 'wb') as f:
            np.save(f,time_array)
            for i in range(noOfCaptures):
                np.save(f,adc2mV(buffersMax[i], chARange, maxADC))


        with open('Data/data_%s.txt'%(time_stamp), 'w') as f:
laboneq.controller.laboneq_logging INFO   Logging initialized from [Default inline config in laboneq.controller.laboneq_logging] logdir is c:\Users\B15measure2\HDAWG\laboneq_output\log
# 2023.08.14 11:33:13.986 laboneq.controller.controller  INFO   VERSION: laboneq 2.11.0
# 2023.08.14 11:33:13.987 laboneq.controller.devices.device_collection INFO   Connecting to data server at 127.0.0.1:8004
# 2023.08.14 11:33:14.114 laboneq.controller.communication INFO   Connected to Zurich Instruments LabOne Data Server version 23.02 at 127.0.0.1:8004
# 2023.08.14 11:33:14.344 laboneq.controller.devices.device_collection INFO   Configuring the device setup
# 2023.08.14 11:33:14.522 laboneq.controller.devices.device_collection INFO   The device setup is configured
# Loaded exp
# 2023.08.14 11:33:15.772 laboneq.compiler.workflow.compiler INFO   Starting LabOne Q Compiler run...
# 2023.08.14 11:33:15.779 laboneq.compiler.scheduler.scheduler INFO   Schedule completed
# 2023.08.14 11:33:47.530 laboneq.compiler.workflow.compiler INFO   Total seqC lines generated: 37
# 2023.08.14 11:33:47.532 laboneq.compiler.workflow.compiler INFO   Total sample points generated: 128
# 2023.08.14 11:33:47.533 laboneq.compiler.workflow.compiler INFO   Finished LabOne Q Compiler run.
# 2023.08.14 11:33:47.809 laboneq.controller.devices.device_collection INFO   Configuring the device setup
# 2023.08.14 11:33:47.994 laboneq.controller.devices.device_collection INFO   The device setup is configured
# 2023.08.14 11:33:48.282 laboneq.controller.controller  INFO   Starting near-time execution...
# 2023.08.14 11:33:50.338 laboneq.controller.controller  INFO   Finished near-time execution.
# Running exp finished
# Rep 0 done. Going to sleep
# 2023.08.14 11:35:50.565 laboneq.controller.laboneq_logging INFO   Logging initialized from [Default inline config in laboneq.controller.laboneq_logging] logdir is c:\Users\B15measure2\HDAWG\laboneq_output\log
# 2023.08.14 11:35:50.567 laboneq.controller.controller  INFO   VERSION: laboneq 2.11.0
# 2023.08.14 11:35:50.567 laboneq.controller.devices.device_collection INFO   Connecting to data server at 127.0.0.1:8004
# 2023.08.14 11:35:50.663 laboneq.controller.communication INFO   Connected to Zurich Instruments LabOne Data Server version 23.02 at 127.0.0.1:8004
# 2023.08.14 11:35:50.893 laboneq.controller.devices.device_collection INFO   Configuring the device setup
# 2023.08.14 11:35:51.072 laboneq.controller.devices.device_collection INFO   The device setup is configured
# Loaded exp
# 2023.08.14 11:35:52.428 laboneq.compiler.workflow.compiler INFO   Starting LabOne Q Compiler run...
# 2023.08.14 11:35:52.437 laboneq.compiler.scheduler.scheduler INFO   Schedule completed
# 2023.08.14 11:36:25.481 laboneq.compiler.workflow.compiler INFO   Total seqC lines generated: 37
# 2023.08.14 11:36:25.483 laboneq.compiler.workflow.compiler INFO   Total sample points generated: 128
# 2023.08.14 11:36:25.484 laboneq.compiler.workflow.compiler INFO   Finished LabOne Q Compiler run.
# 2023.08.14 11:36:25.770 laboneq.controller.devices.device_collection INFO   Configuring the device setup
# 2023.08.14 11:36:25.948 laboneq.controller.devices.device_collection INFO   The device setup is configured
# 2023.08.14 11:36:26.246 laboneq.controller.controller  INFO   Starting near-time execution...
# 2023.08.14 11:36:28.307 laboneq.controller.controller  INFO   Finished near-time execution.
# Running exp finished
# Rep 0 done. Going to sleep
# 2023.08.14 11:38:28.514 laboneq.controller.laboneq_logging INFO   Logging initialized from [Default inline config in laboneq.controller.laboneq_logging] logdir is c:\Users\B15measure2\HDAWG\laboneq_output\log
# 2023.08.14 11:38:28.516 laboneq.controller.controller  INFO   VERSION: laboneq 2.11.0
# 2023.08.14 11:38:28.517 laboneq.controller.devices.device_collection INFO   Connecting to data server at 127.0.0.1:8004
# 2023.08.14 11:38:28.640 laboneq.controller.communication INFO   Connected to Zurich Instruments LabOne Data Server version 23.02 at 127.0.0.1:8004
# 2023.08.14 11:38:28.872 laboneq.controller.devices.device_collection INFO   Configuring the device setup
# 2023.08.14 11:38:29.052 laboneq.controller.devices.device_collection INFO   The device setup is configured
# Loaded exp
# 2023.08.14 11:38:30.322 laboneq.compiler.workflow.compiler INFO   Starting LabOne Q Compiler run...
# 2023.08.14 11:38:30.328 laboneq.compiler.scheduler.scheduler INFO   Schedule completed
# 2023.08.14 11:39:02.460 laboneq.compiler.workflow.compiler INFO   Total seqC lines generated: 37
# 2023.08.14 11:39:02.461 laboneq.compiler.workflow.compiler INFO   Total sample points generated: 128
# 2023.08.14 11:39:02.462 laboneq.compiler.workflow.compiler INFO   Finished LabOne Q Compiler run.
# 2023.08.14 11:39:02.727 laboneq.controller.devices.device_collection INFO   Configuring the device setup
# 2023.08.14 11:39:02.914 laboneq.controller.devices.device_collection INFO   The device setup is configured
# 2023.08.14 11:39:03.231 laboneq.controller.controller  INFO   Starting near-time execution...
# 2023.08.14 11:39:05.304 laboneq.controller.controller  INFO   Finished near-time execution.
# Running exp finished
# Rep 0 done. Going to sleep
# 2023.08.14 11:41:05.543 laboneq.controller.laboneq_logging INFO   Logging initialized from [Default inline config in laboneq.controller.laboneq_logging] logdir is c:\Users\B15measure2\HDAWG\laboneq_output\log
# 2023.08.14 11:41:05.546 laboneq.controller.controller  INFO   VERSION: laboneq 2.11.0
# 2023.08.14 11:41:05.548 laboneq.controller.devices.device_collection INFO   Connecting to data server at 127.0.0.1:8004
# 2023.08.14 11:41:05.683 laboneq.controller.communication INFO   Connected to Zurich Instruments LabOne Data Server version 23.02 at 127.0.0.1:8004
# 2023.08.14 11:41:05.914 laboneq.controller.devices.device_collection INFO   Configuring the device setup
# 2023.08.14 11:41:06.096 laboneq.controller.devices.device_collection INFO   The device setup is configured
# Loaded exp
# 2023.08.14 11:41:07.355 laboneq.compiler.workflow.compiler INFO   Starting LabOne Q Compiler run...
# 2023.08.14 11:41:07.360 laboneq.compiler.scheduler.scheduler INFO   Schedule completed
# 2023.08.14 11:41:40.930 laboneq.compiler.workflow.compiler INFO   Total seqC lines generated: 37
# 2023.08.14 11:41:40.932 laboneq.compiler.workflow.compiler INFO   Total sample points generated: 128
# 2023.08.14 11:41:40.933 laboneq.compiler.workflow.compiler INFO   Finished LabOne Q Compiler run.
# 2023.08.14 11:41:41.201 laboneq.controller.devices.device_collection INFO   Configuring the device setup
# 2023.08.14 11:41:41.374 laboneq.controller.devices.device_collection INFO   The device setup is configured
# 2023.08.14 11:41:41.665 laboneq.controller.controller  INFO   Starting near-time execution...
# 2023.08.14 11:41:43.726 laboneq.controller.controller  INFO   Finished near-time execution.
# Running exp finished
# Rep 0 done. Going to sleep
# 2023.08.14 11:43:43.957 laboneq.controller.laboneq_logging INFO   Logging initialized from [Default inline config in laboneq.controller.laboneq_logging] logdir is c:\Users\B15measure2\HDAWG\laboneq_output\log
# 2023.08.14 11:43:43.958 laboneq.controller.controller  INFO   VERSION: laboneq 2.11.0
# 2023.08.14 11:43:43.959 laboneq.controller.devices.device_collection INFO   Connecting to data server at 127.0.0.1:8004
# 2023.08.14 11:43:44.069 laboneq.controller.communication INFO   Connected to Zurich Instruments LabOne Data Server version 23.02 at 127.0.0.1:8004
# 2023.08.14 11:43:44.302 laboneq.controller.devices.device_collection INFO   Configuring the device setup
# 2023.08.14 11:43:44.481 laboneq.controller.devices.device_collection INFO   The device setup is configured
# Loaded exp
# 2023.08.14 11:43:45.760 laboneq.compiler.workflow.compiler INFO   Starting LabOne Q Compiler run...
# 2023.08.14 11:43:45.765 laboneq.compiler.scheduler.scheduler INFO   Schedule completed
# 2023.08.14 11:44:19.072 laboneq.compiler.workflow.compiler INFO   Total seqC lines generated: 37
# 2023.08.14 11:44:19.074 laboneq.compiler.workflow.compiler INFO   Total sample points generated: 128
# 2023.08.14 11:44:19.079 laboneq.compiler.workflow.compiler INFO   Finished LabOne Q Compiler run.
# 2023.08.14 11:44:19.362 laboneq.controller.devices.device_collection INFO   Configuring the device setup
# 2023.08.14 11:44:19.552 laboneq.controller.devices.device_collection INFO   The device setup is configured
# 2023.08.14 11:44:19.847 laboneq.controller.controller  INFO   Starting near-time execution...
# 2023.08.14 11:44:21.913 laboneq.controller.controller  INFO   Finished near-time execution.
# Running exp finished
# Rep 0 done. Going to sleep
# 2023.08.14 11:46:22.129 laboneq.controller.laboneq_logging INFO   Logging initialized from [Default inline config in laboneq.controller.laboneq_logging] logdir is c:\Users\B15measure2\HDAWG\laboneq_output\log
# 2023.08.14 11:46:22.130 laboneq.controller.controller  INFO   VERSION: laboneq 2.11.0
# 2023.08.14 11:46:22.131 laboneq.controller.devices.device_collection INFO   Connecting to data server at 127.0.0.1:8004
# 2023.08.14 11:46:22.250 laboneq.controller.communication INFO   Connected to Zurich Instruments LabOne Data Server version 23.02 at 127.0.0.1:8004
# 2023.08.14 11:46:22.477 laboneq.controller.devices.device_collection INFO   Configuring the device setup
# 2023.08.14 11:46:22.659 laboneq.controller.devices.device_collection INFO   The device setup is configured
# Loaded exp
# 2023.08.14 11:46:23.980 laboneq.compiler.workflow.compiler INFO   Starting LabOne Q Compiler run...
# 2023.08.14 11:46:23.985 laboneq.compiler.scheduler.scheduler INFO   Schedule completed
# 2023.08.14 11:46:56.056 laboneq.compiler.workflow.compiler INFO   Total seqC lines generated: 37
# 2023.08.14 11:46:56.059 laboneq.compiler.workflow.compiler INFO   Total sample points generated: 128
# 2023.08.14 11:46:56.060 laboneq.compiler.workflow.compiler INFO   Finished LabOne Q Compiler run.
# 2023.08.14 11:46:56.320 laboneq.controller.devices.device_collection INFO   Configuring the device setup
# 2023.08.14 11:46:56.495 laboneq.controller.devices.device_collection INFO   The device setup is configured
# 2023.08.14 11:46:56.781 laboneq.controller.controller  INFO   Starting near-time execution...
# 2023.08.14 11:46:58.843 laboneq.controller.controller  INFO   Finished near-time execution.
# Running exp finished
# Rep 0 done. Going to sleep
# 2023.08.14 11:48:59.098 laboneq.controller.laboneq_logging INFO   Logging initialized from [Default inline config in laboneq.controller.laboneq_logging] logdir is c:\Users\B15measure2\HDAWG\laboneq_output\log
# 2023.08.14 11:48:59.101 laboneq.controller.controller  INFO   VERSION: laboneq 2.11.0
# 2023.08.14 11:48:59.104 laboneq.controller.devices.device_collection INFO   Connecting to data server at 127.0.0.1:8004
# 2023.08.14 11:48:59.195 laboneq.controller.communication INFO   Connected to Zurich Instruments LabOne Data Server version 23.02 at 127.0.0.1:8004
# 2023.08.14 11:48:59.454 laboneq.controller.devices.device_collection INFO   Configuring the device setup
# 2023.08.14 11:48:59.651 laboneq.controller.devices.device_collection INFO   The device setup is configured
# Loaded exp
# 2023.08.14 11:49:00.979 laboneq.compiler.workflow.compiler INFO   Starting LabOne Q Compiler run...
# 2023.08.14 11:49:00.984 laboneq.compiler.scheduler.scheduler INFO   Schedule completed
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
